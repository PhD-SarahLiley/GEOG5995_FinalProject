# %% [markdown]
# # GEOG5995M Final Assignment
#
# Student ID number:

# %%
# read in required packages

# %%
# import required packages

# for visualisation
import seaborn as sns
import matplotlib.pyplot as plt

# for data manipulation
import pandas as pd
import numpy as np

# %%
activity_all = pd.read_csv('SALT Data File (Descriptions).csv')
# Out:
# C:\Users\sarah\AppData\Local\Temp\ipykernel_7808\2574619173.py:1: DtypeWarning: Columns (3,7,8,9,13,16,17,18,19,22,23,24,28,31,34,35,36,37,40,41,42,43,44,45,46,48,49,50,51,52,53,54) have mixed types. Specify dtype option on import or set low_memory=False.
#   activity_all = pd.read_csv('SALT Data File (Descriptions).csv')

# %%
#all_over65 = (activity_all.loc[activity_all['UUID']=='7611207'])
all_over65 = activity_all[activity_all["UUID"] == 7611207]

# %% [markdown]
# # PHY

# %%
all_over65.head()
# Out:
#         GEOGRAPHY_LEVEL    SHEET TABLE ADDITIONAL_CELLS   DATA_LEVEL  \
# 158755  Local Authority  LTS001B    1B              NaN  TABLE TOTAL
# 158756  Local Authority  LTS001B    1B              NaN  TABLE TOTAL
# 158757  Local Authority  LTS001B    1B              NaN  TABLE TOTAL
# 158758  Local Authority  LTS001B    1B              NaN  TABLE TOTAL
# 158759  Local Authority  LTS001B    1B              NaN  TABLE TOTAL
#
#         FY_Ending     UUID CASSR_CODE GEOGRAPHY_CODE    DH_GEOGRAPHY_NAME  \
# 158755       2022  7611207        107      E08000021  Newcastle upon Tyne
# 158756       2022  7611207        109      E08000023       South Tyneside
# 158757       2022  7611207        114      E06000004     Stockton-on-Tees
# 158758       2022  7611207        210      E08000033           Calderdale
# 158759       2022  7611207        213      E08000036            Wakefield
#
#         ... SignificantEvent_Key ClientCount_Key CarerAgeBand_Key  \
# 158755  ...                  NaN             NaN              NaN
# 158756  ...                  NaN             NaN              NaN
# 158757  ...                  NaN             NaN              NaN
# 158758  ...                  NaN             NaN              NaN
# 158759  ...                  NaN             NaN              NaN
#
#        StatusOfCaredForPerson_Key MethodOfAssessment_Key  \
# 158755                        NaN                    NaN
# 158756                        NaN                    NaN
# 158757                        NaN                    NaN
# 158758                        NaN                    NaN
# 158759                        NaN                    NaN
#
#        EmploymentStatusType_Key EmploymentStatusDesc_Key LivingStatusType_Key  \
# 158755                      NaN                      NaN                  NaN
# 158756                      NaN                      NaN                  NaN
# 158757                      NaN                      NaN                  NaN
# 158758                      NaN                      NaN                  NaN
# 158759                      NaN                      NaN                  NaN
#
#        LivingStatusDesc_Key ITEMVALUE
# 158755                  NaN      2255
# 158756                  NaN      1575
# 158757                  NaN      1610
# 158758                  NaN      1415
# 158759                  NaN      2450
#
# [5 rows x 56 columns]

# %%
deprivation_olderpeople = pd.read_excel('File_11_-_IoD2019_Local_Authority_District_Summaries__upper-tier__.xlsx', sheet_name='IDAOPI')

# %% [markdown]
# This is an example block of mardown text I want to reference <a href="#ref1">[1]</a>. I might need to add some more citations <a href="#ref2">[2]</a><a href="#ref2">[3]</a>

# %%
activity_deprivation  = pd.merge(all_over65, deprivation_olderpeople,  left_on='GEOGRAPHY_CODE', right_on='Upper Tier Local Authority District code (2019)', how='left')

# %%
activity_deprivation.head()
# Out:
#    GEOGRAPHY_LEVEL    SHEET TABLE ADDITIONAL_CELLS   DATA_LEVEL  FY_Ending  \
# 0  Local Authority  LTS001B    1B              NaN  TABLE TOTAL       2022
# 1  Local Authority  LTS001B    1B              NaN  TABLE TOTAL       2022
# 2  Local Authority  LTS001B    1B              NaN  TABLE TOTAL       2022
# 3  Local Authority  LTS001B    1B              NaN  TABLE TOTAL       2022
# 4  Local Authority  LTS001B    1B              NaN  TABLE TOTAL       2022
#
#       UUID CASSR_CODE GEOGRAPHY_CODE    DH_GEOGRAPHY_NAME  ...  \
# 0  7611207        107      E08000021  Newcastle upon Tyne  ...
# 1  7611207        109      E08000023       South Tyneside  ...
# 2  7611207        114      E06000004     Stockton-on-Tees  ...
# 3  7611207        210      E08000033           Calderdale  ...
# 4  7611207        213      E08000036            Wakefield  ...
#
#   LivingStatusDesc_Key ITEMVALUE  \
# 0                  NaN      2255
# 1                  NaN      1575
# 2                  NaN      1610
# 3                  NaN      1415
# 4                  NaN      2450
#
#   Upper Tier Local Authority District code (2019)  \
# 0                                       E08000021
# 1                                       E08000023
# 2                                       E06000004
# 3                                       E08000033
# 4                                       E08000036
#
#   Upper Tier Local Authority District name (2019) IDAOPI - Average rank   \
# 0                             Newcastle upon Tyne               19812.19
# 1                                  South Tyneside               21479.71
# 2                                Stockton-on-Tees               15589.56
# 3                                      Calderdale               14673.54
# 4                                       Wakefield               15818.98
#
#   IDAOPI - Rank of average rank  IDAOPI - Average score   \
# 0                           38.0                   0.218
# 1                           28.0                   0.214
# 2                           85.0                   0.160
# 3                           92.0                   0.140
# 4                           82.0                   0.145
#
#   IDAOPI - Rank of average score   \
# 0                            31.0
# 1                            33.0
# 2                            74.0
# 3                            88.0
# 4                            86.0
#
#   IDAOPI - Proportion  of LSOAs in most deprived 10% nationally   \
# 0                                             0.2857
# 1                                             0.1176
# 2                                             0.1417
# 3                                             0.0781
# 4                                             0.0335
#
#   IDAOPI - Rank of proportion of LSOAs in most deprived 10% nationally
# 0                                               17.0
# 1                                               56.0
# 2                                               50.0
# 3                                               67.0
# 4                                               95.0
#
# [5 rows x 64 columns]

# %% [markdown]
# Data Visualisation
# - Don't forget to present your final two data visualisation (one spatial and one non-spatial) and the justifications about the deicsisions you made whilst preparing and visualising the data.

# %% [markdown]
# ## References
# <p><a href="add_url_here">[1]</a>Footnote citation goes here</p>
# <p><a href="https://github.com/FrancescaPontin/GEOG5995">[2]</a>GEOG5995M course materials</p>
# <p><a href="add_url_here">[3]</a>Citation 3</p>
